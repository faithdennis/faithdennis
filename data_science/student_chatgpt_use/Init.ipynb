# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting statsmodels==0.14.4
#   Downloading statsmodels-0.14.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 126.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.4->-r ./requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels==0.14.4->-r ./requirements.txt (line 2)) (21.3)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<3,>=1.22.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.4->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.4->-r ./requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=21.3->statsmodels==0.14.4->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels==0.14.4->-r ./requirements.txt (line 2)) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e6b9c6c4-ec4a-491e-ae33-581131c8d8d8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
